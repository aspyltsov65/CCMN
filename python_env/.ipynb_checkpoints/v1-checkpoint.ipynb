# %%
from bs4 import BeautifulSoup
import requests
import sys
import json
import urllib3
urllib3.disable_warnings()

username = 'RO'
password = 'just4reading'
hostname = 'https://cisco-cmx.unit.ua/'
query_mac = 'api/location/v1/history/clients/'
query_active = 'api/location/v2/clients/'
query_allhistory = 'api/location/v1/history/clients'
mac_ad = '00%3A03%3Aac%3A33%3A94%3A0e'

def parse(data):
    data = json.loads(data)
    #print (data)
    data = data['Records'][0]
    mac = data['macAddress']
    x = data['mapCoordinate']['x']
    y = data['mapCoordinate']['y']
    ip = data['ipAddress'][0]
    userName = data['userName']
    ssid = data['ssId']
    print ('IP address: ', ip)
    print ('macAddress:', mac)
    print ('ssId:     ', ssid)
    print ('UserName: ', userName)
    print ('x: ', x)
    print ('y: ', y)
    #print (data)
    
def parse_all(data):
    data = json.loads(data)
    for mac in data:
        if mac['ipAddress']:
            print ('macAddress: ', mac['macAddress'])
            print ('ipAddress: ', mac['ipAddress'][0])
            print ('ssId: ', mac['ssId'])
            print ('Area: ', mac['mapInfo']['mapHierarchyString'])
            print ('manufacturer: ', mac['manufacturer'])
            print ('First Located Time: ', mac['statistics']['firstLocatedTime'])
            print ('Last Located Time: ', mac['statistics']['lastLocatedTime'])
            print ('userName: ', mac['userName'])
            print ('RSSI: ', mac['statistics']['maxDetectedRssi']['rssi'])
            print ('x: ', mac['mapCoordinate']['x'])
            print ('y: ', mac['mapCoordinate']['y'])
            print ('\n')
        

try:
    session = requests.Session()
    session.verify = False
    session.auth = (username, password)
    auth = session.post(hostname)
    response = session.get(hostname + query_active)
    data = response.text

    parse_all(data)
except:
    print(sys.exc_info()[1])
# Out:
# macAddress:  fc:53:9e:aa:12:d0
# ipAddress:  10.85.145.84
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Shanghai Wind Technologies Co.,Ltd
# First Located Time:  2019-04-19T16:59:47.651+0300
# Last Located Time:  2019-04-19T19:50:47.651+0300
# userName:  dmlitvin
# RSSI:  -46
# x:  1388.8049
# y:  47.290173
#
#
# macAddress:  f8:27:93:52:6e:07
# ipAddress:  10.87.87.109
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:31:51.650+0300
# Last Located Time:  2019-04-19T19:51:05.648+0300
# userName:
# RSSI:  -42
# x:  691.90546
# y:  46.65203
#
#
# macAddress:  f4:60:e2:f5:c4:02
# ipAddress:  10.85.144.169
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T18:54:29.648+0300
# Last Located Time:  2019-04-19T19:48:38.501+0300
# userName:  akoropet
# RSSI:  -85
# x:  252.2609
# y:  47.597454
#
#
# macAddress:  dc:a9:04:40:7c:bb
# ipAddress:  10.85.146.248
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:26:27.653+0300
# Last Located Time:  2019-04-19T19:50:47.647+0300
# userName:  olrudenk
# RSSI:  -64
# x:  1044.0
# y:  385.04596
#
#
# macAddress:  d8:ce:3a:4e:db:51
# ipAddress:  10.87.80.55
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T19:43:08.424+0300
# Last Located Time:  2019-04-19T19:48:38.503+0300
# userName:
# RSSI:  -53
# x:  871.5801
# y:  687.13434
#
#
# macAddress:  cc:73:14:14:c7:a0
# ipAddress:  10.85.149.177
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  HONG KONG WHEATEK TECHNOLOGY LIMITED
# First Located Time:  2019-04-19T19:15:53.651+0300
# Last Located Time:  2019-04-19T19:48:38.518+0300
# userName:  dshpack
# RSSI:  -52
# x:  741.97955
# y:  128.52646
#
#
# macAddress:  cc:2d:e0:2b:20:bb
# ipAddress:  10.87.85.28
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Routerboard.com
# First Located Time:  2019-04-19T16:00:51.650+0300
# Last Located Time:  2019-04-19T19:51:01.650+0300
# userName:
# RSSI:  -45
# x:  646.3545
# y:  474.66922
#
#
# macAddress:  c0:f4:e6:e6:01:63
# ipAddress:  10.85.144.170
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  HUAWEI TECHNOLOGIES CO.,LTD
# First Located Time:  2019-04-19T19:16:09.650+0300
# Last Located Time:  2019-04-19T19:48:38.511+0300
# userName:  hmuravch
# RSSI:  -41
# x:  1397.8601
# y:  40.91015
#
#
# macAddress:  c0:1a:da:4e:33:f8
# ipAddress:  10.87.82.34
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T16:46:49.648+0300
# Last Located Time:  2019-04-19T19:51:09.647+0300
# userName:
# RSSI:  -39
# x:  1114.734
# y:  267.18356
#
#
# macAddress:  b8:27:eb:f1:b9:c2
# ipAddress:  10.86.1.14
# ssId:  X.Teams
# Area:  System Campus>UNIT.Factory>3rd_Floor>Coverage Area-3rd_Floor
# manufacturer:  Raspberry Pi Foundation
# First Located Time:  2019-03-25T12:27:19.651+0200
# Last Located Time:  2019-04-19T19:50:35.651+0300
# userName:
# RSSI:  -45
# x:  1005.88446
# y:  199.10503
#
#
# macAddress:  b8:27:eb:41:0d:66
# ipAddress:  10.86.1.24
# ssId:  X.Teams
# Area:  System Campus>UNIT.Factory>3rd_Floor>Coverage Area-3rd_Floor
# manufacturer:  Raspberry Pi Foundation
# First Located Time:  2019-03-27T18:59:19.651+0200
# Last Located Time:  2019-04-19T19:50:51.648+0300
# userName:
# RSSI:  -48
# x:  1003.0838
# y:  212.20685
#
#
# macAddress:  b4:ef:fa:ed:0c:0e
# ipAddress:  10.87.99.196
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Lemobile Information Technology (Beijing) Co., Ltd.
# First Located Time:  2019-04-19T12:29:39.653+0300
# Last Located Time:  2019-04-19T19:49:25.648+0300
# userName:
# RSSI:  -39
# x:  861.72327
# y:  690.3673
#
#
# macAddress:  a4:6c:f1:cb:85:87
# ipAddress:  10.87.91.209
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Samsung Electronics Co.,Ltd
# First Located Time:  2019-04-19T19:11:07.655+0300
# Last Located Time:  2019-04-19T19:51:13.647+0300
# userName:
# RSSI:  -77
# x:  129.47841
# y:  251.31151
#
#
# macAddress:  9c:2e:a1:90:37:ef
# ipAddress:  10.85.146.113
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T14:48:19.648+0300
# Last Located Time:  2019-04-19T19:48:38.507+0300
# userName:  vuslysty
# RSSI:  -85
# x:  852.3528
# y:  694.6542
#
#
# macAddress:  98:9e:63:27:5e:3c
# ipAddress:  10.87.82.44
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-17T13:46:51.650+0300
# Last Located Time:  2019-04-19T19:48:38.502+0300
# userName:
# RSSI:  -41
# x:  1044.0
# y:  390.9126
#
#
# macAddress:  90:94:97:6b:36:a1
# ipAddress:  10.87.88.72
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  HUAWEI TECHNOLOGIES CO.,LTD
# First Located Time:  2019-04-19T17:20:45.649+0300
# Last Located Time:  2019-04-19T19:48:38.493+0300
# userName:
# RSSI:  -49
# x:  1396.9287
# y:  40.977917
#
#
# macAddress:  80:be:05:32:a8:f6
# ipAddress:  10.87.118.252
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T15:08:53.647+0300
# Last Located Time:  2019-04-19T19:51:13.646+0300
# userName:
# RSSI:  -64
# x:  1314.2839
# y:  239.48663
#
#
# macAddress:  78:4f:43:9c:47:1b
# ipAddress:  10.87.107.82
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:03:21.644+0300
# Last Located Time:  2019-04-19T19:48:38.495+0300
# userName:
# RSSI:  -60
# x:  1044.0
# y:  328.67648
#
#
# macAddress:  74:df:bf:e9:db:25
# ipAddress:  10.86.150.129
# ssId:  X.Teams
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Liteon Technology Corporation
# First Located Time:  2019-04-19T17:28:01.652+0300
# Last Located Time:  2019-04-19T19:50:55.649+0300
# userName:
# RSSI:  -29
# x:  205.52232
# y:  555.09656
#
#
# macAddress:  70:73:cb:45:63:83
# ipAddress:  10.87.120.139
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:53:48.057+0300
# Last Located Time:  2019-04-19T19:51:09.650+0300
# userName:
# RSSI:  -62
# x:  974.70105
# y:  414.3959
#
#
# macAddress:  70:3a:51:0d:86:f3
# ipAddress:  10.87.82.7
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T17:03:27.650+0300
# Last Located Time:  2019-04-19T19:48:38.499+0300
# userName:
# RSSI:  -50
# x:  966.494
# y:  570.845
#
#
# macAddress:  6c:e8:5c:d9:d4:46
# ipAddress:  10.87.79.140
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T18:37:47.649+0300
# Last Located Time:  2019-04-19T19:48:38.490+0300
# userName:
# RSSI:  -63
# x:  1183.6139
# y:  372.3705
#
#
# macAddress:  68:96:7b:5a:04:4c
# ipAddress:  10.87.119.197
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:52:56.044+0300
# Last Located Time:  2019-04-19T19:48:38.489+0300
# userName:
# RSSI:  -57
# x:  1044.0
# y:  252.03188
#
#
# macAddress:  54:14:73:a0:7b:3e
# ipAddress:  10.87.111.168
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Wingtech Group (HongKongï¼Limited
# First Located Time:  2019-04-19T14:52:21.650+0300
# Last Located Time:  2019-04-19T19:48:38.483+0300
# userName:
# RSSI:  -48
# x:  706.83563
# y:  53.489014
#
#
# macAddress:  50:8f:4c:4b:4a:c4
# ipAddress:  10.87.115.157
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T17:21:47.647+0300
# Last Located Time:  2019-04-19T19:48:38.493+0300
# userName:
# RSSI:  -55
# x:  184.6865
# y:  555.8692
#
#
# macAddress:  40:83:1d:28:9d:ff
# ipAddress:  10.87.93.134
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T14:50:27.648+0300
# Last Located Time:  2019-04-19T19:50:27.704+0300
# userName:
# RSSI:  -61
# x:  697.6958
# y:  245.88954
#
#
# macAddress:  28:a0:2b:ec:16:4c
# ipAddress:  10.85.149.211
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T12:24:21.646+0300
# Last Located Time:  2019-04-19T19:48:38.490+0300
# userName:  opavliuk
# RSSI:  -55
# x:  965.7979
# y:  587.6499
#
#
# macAddress:  1c:cd:e5:23:8e:8c
# ipAddress:  10.85.150.123
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Shanghai Wind Technologies Co.,Ltd
# First Located Time:  2019-04-19T18:39:13.648+0300
# Last Located Time:  2019-04-19T19:50:43.654+0300
# userName:  inazarin
# RSSI:  -40
# x:  1123.557
# y:  52.929634
#
#
# macAddress:  04:b1:67:29:f0:72
# ipAddress:  10.85.147.112
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T13:29:27.651+0300
# Last Located Time:  2019-04-19T19:48:38.497+0300
# userName:  rzero
# RSSI:  -60
# x:  1509.7428
# y:  701.31836
#
#
# macAddress:  00:08:22:36:dc:fc
# ipAddress:  10.87.82.170
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  InPro Comm
# First Located Time:  2019-04-19T18:06:09.653+0300
# Last Located Time:  2019-04-19T19:48:38.477+0300
# userName:
# RSSI:  -91
# x:  189.5332
# y:  28.114359
#
#
# macAddress:  f0:24:75:d4:96:09
# ipAddress:  10.85.144.182
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T16:01:39.646+0300
# Last Located Time:  2019-04-19T19:49:29.649+0300
# userName:  solefir
# RSSI:  -47
# x:  869.78265
# y:  691.80817
#
#
# macAddress:  e8:36:17:5d:6a:14
# ipAddress:  10.81.1.41
# ssId:  UNIT Factory (adm)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T19:03:47.651+0300
# Last Located Time:  2019-04-19T19:48:38.521+0300
# userName:
# RSSI:  -58
# x:  958.14325
# y:  530.2808
#
#
# macAddress:  d4:ae:05:9e:b1:33
# ipAddress:  10.87.86.234
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Samsung Electronics Co.,Ltd
# First Located Time:  2019-04-19T16:57:19.653+0300
# Last Located Time:  2019-04-19T19:48:38.506+0300
# userName:
# RSSI:  -39
# x:  687.6786
# y:  34.399555
#
#
# macAddress:  c0:a6:00:b4:31:df
# ipAddress:  10.87.79.86
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T18:17:55.646+0300
# Last Located Time:  2019-04-19T19:51:09.647+0300
# userName:
# RSSI:  -65
# x:  1396.8036
# y:  41.605686
#
#
# macAddress:  b8:27:eb:e9:2e:66
# ipAddress:  10.86.1.30
# ssId:  X.Teams
# Area:  System Campus>UNIT.Factory>3rd_Floor>Coverage Area-3rd_Floor
# manufacturer:  Raspberry Pi Foundation
# First Located Time:  2019-04-13T20:29:35.649+0300
# Last Located Time:  2019-04-19T19:50:51.651+0300
# userName:
# RSSI:  -52
# x:  1001.75244
# y:  219.8125
#
#
# macAddress:  b0:e2:35:cf:b5:ae
# ipAddress:  10.85.145.181
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T19:00:37.649+0300
# Last Located Time:  2019-04-19T19:50:31.649+0300
# userName:  hlriabts
# RSSI:  -57
# x:  958.24585
# y:  565.80536
#
#
# macAddress:  b0:e1:7e:08:90:f7
# ipAddress:  10.87.86.124
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  HUAWEI TECHNOLOGIES CO.,LTD
# First Located Time:  2019-04-19T19:34:47.657+0300
# Last Located Time:  2019-04-19T19:50:17.651+0300
# userName:
# RSSI:  -36
# x:  184.72742
# y:  554.24744
#
#
# macAddress:  a8:88:08:35:99:94
# ipAddress:  10.87.118.196
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T14:59:32.372+0300
# Last Located Time:  2019-04-19T19:50:55.645+0300
# userName:
# RSSI:  -51
# x:  867.29205
# y:  355.77228
#
#
# macAddress:  98:9e:63:69:bf:88
# ipAddress:  10.87.111.229
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T16:07:23.649+0300
# Last Located Time:  2019-04-19T19:48:38.507+0300
# userName:
# RSSI:  -64
# x:  1086.127
# y:  276.75925
#
#
# macAddress:  98:9e:63:2b:1c:34
# ipAddress:  10.81.1.30
# ssId:  UNIT Factory (adm)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-18T09:34:33.648+0300
# Last Located Time:  2019-04-19T19:50:39.649+0300
# userName:
# RSSI:  -40
# x:  1044.0
# y:  390.58493
#
#
# macAddress:  98:9e:63:27:e5:ce
# ipAddress:  10.82.1.121
# ssId:  bocal
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-03-28T10:46:33.647+0200
# Last Located Time:  2019-04-19T19:49:17.648+0300
# userName:
# RSSI:  -43
# x:  244.47183
# y:  197.90489
#
#
# macAddress:  98:9e:63:27:5c:c6
# ipAddress:  10.87.79.117
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>3rd_Floor>Coverage Area-3rd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-18T11:41:41.648+0300
# Last Located Time:  2019-04-19T19:48:38.491+0300
# userName:
# RSSI:  -34
# x:  1016.7003
# y:  251.02985
#
#
# macAddress:  98:3b:8f:ac:46:9e
# ipAddress:  10.87.79.68
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  None
# First Located Time:  2019-04-19T18:35:29.649+0300
# Last Located Time:  2019-04-19T19:48:38.482+0300
# userName:
# RSSI:  -66
# x:  1172.2238
# y:  365.07944
#
#
# macAddress:  94:87:e0:7c:a0:b6
# ipAddress:  10.87.83.4
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T19:24:09.646+0300
# Last Located Time:  2019-04-19T19:48:38.497+0300
# userName:
# RSSI:  -46
# x:  184.8857
# y:  557.1204
#
#
# macAddress:  7c:76:68:bb:d3:28
# ipAddress:  10.87.85.95
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  HUAWEI TECHNOLOGIES CO.,LTD
# First Located Time:  2019-04-19T19:20:29.655+0300
# Last Located Time:  2019-04-19T19:48:38.492+0300
# userName:
# RSSI:  -68
# x:  799.5158
# y:  664.462
#
#
# macAddress:  78:4b:87:63:70:f9
# ipAddress:  10.85.144.196
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Murata Manufacturing Co., Ltd.
# First Located Time:  2019-04-19T18:02:39.648+0300
# Last Located Time:  2019-04-19T19:48:38.479+0300
# userName:  ikoloshy
# RSSI:  -37
# x:  1177.4906
# y:  361.30652
#
#
# macAddress:  70:28:8b:88:91:f4
# ipAddress:  10.87.101.16
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Samsung Electronics Co.,Ltd
# First Located Time:  2019-04-19T17:46:59.651+0300
# Last Located Time:  2019-04-19T19:48:38.495+0300
# userName:
# RSSI:  -53
# x:  1042.0688
# y:  431.3259
#
#
# macAddress:  6c:70:9f:03:34:ea
# ipAddress:  10.81.1.202
# ssId:  UNIT Factory (adm)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-18T22:20:29.647+0300
# Last Located Time:  2019-04-19T19:48:38.489+0300
# userName:
# RSSI:  -51
# x:  382.50168
# y:  59.902695
#
#
# macAddress:  68:db:ca:cb:58:c6
# ipAddress:  10.85.144.164
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T19:05:53.651+0300
# Last Located Time:  2019-04-19T19:48:38.485+0300
# userName:  amazhara
# RSSI:  -54
# x:  961.61066
# y:  542.5891
#
#
# macAddress:  64:cc:2e:bb:bb:06
# ipAddress:  10.85.144.176
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T18:37:29.651+0300
# Last Located Time:  2019-04-19T19:48:38.499+0300
# userName:  eamielin
# RSSI:  -64
# x:  60.08196
# y:  204.16792
#
#
# macAddress:  64:70:33:a6:83:4f
# ipAddress:  10.82.1.120
# ssId:  bocal
# Area:  System Campus>UNIT.Factory>1st_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:30:37.646+0300
# Last Located Time:  2019-04-19T19:51:05.648+0300
# userName:
# RSSI:  -44
# x:  572.67694
# y:  0.0
#
#
# macAddress:  64:70:33:a5:e4:e8
# ipAddress:  10.87.84.46
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T14:50:15.652+0300
# Last Located Time:  2019-04-19T19:48:38.492+0300
# userName:
# RSSI:  -44
# x:  965.2151
# y:  582.2912
#
#
# macAddress:  5c:a8:6a:71:f1:23
# ipAddress:  10.87.117.40
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  HUAWEI TECHNOLOGIES CO.,LTD
# First Located Time:  2019-04-19T19:30:53.652+0300
# Last Located Time:  2019-04-19T19:51:09.649+0300
# userName:
# RSSI:  -62
# x:  713.8135
# y:  37.74014
#
#
# macAddress:  3c:dc:bc:97:9a:eb
# ipAddress:  10.87.79.92
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Samsung Electronics Co.,Ltd
# First Located Time:  2019-04-19T19:11:15.646+0300
# Last Located Time:  2019-04-19T19:50:38.408+0300
# userName:
# RSSI:  -56
# x:  1182.3877
# y:  384.47638
#
#
# macAddress:  38:f2:3e:66:54:e4
# ipAddress:  10.87.98.100
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>2nd_Floor
# manufacturer:  Microsoft Mobile Oy
# First Located Time:  2019-04-19T18:32:13.650+0300
# Last Located Time:  2019-04-19T19:49:55.649+0300
# userName:
# RSSI:  -34
# x:  668.12305
# y:  0.0
#
#
# macAddress:  38:a4:ed:6d:54:61
# ipAddress:  10.85.147.245
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Xiaomi Communications Co Ltd
# First Located Time:  2019-04-19T19:44:07.658+0300
# Last Located Time:  2019-04-19T19:50:46.416+0300
# userName:  pdemian
# RSSI:  -55
# x:  688.51904
# y:  44.995003
#
#
# macAddress:  28:f0:76:04:d5:fc
# ipAddress:  10.81.1.11
# ssId:  UNIT Factory (adm)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T19:42:13.651+0300
# Last Located Time:  2019-04-19T19:48:38.488+0300
# userName:
# RSSI:  -35
# x:  1044.0
# y:  392.9604
#
#
# macAddress:  20:c9:d0:7e:ec:d7
# ipAddress:  10.87.79.110
# ssId:  UNIT Factory (public)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Apple, Inc.
# First Located Time:  2019-04-19T18:34:33.933+0300
# Last Located Time:  2019-04-19T19:49:58.467+0300
# userName:
# RSSI:  -57
# x:  584.0025
# y:  456.4214
#
#
# macAddress:  14:16:9e:1b:13:c1
# ipAddress:  10.85.146.215
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>2nd_Floor>Coverage Area_2nd_Floor
# manufacturer:  Wingtech Group (HongKongï¼Limited
# First Located Time:  2019-04-19T19:10:01.656+0300
# Last Located Time:  2019-04-19T19:48:38.500+0300
# userName:  omaslov
# RSSI:  -60
# x:  710.6113
# y:  56.85731
#
#
# macAddress:  00:03:ac:33:94:0e
# ipAddress:  10.85.144.203
# ssId:  UNIT Factory (student)
# Area:  System Campus>UNIT.Factory>1st_Floor>Coverage_Area-First_Floor
# manufacturer:  Fronius Schweissmaschinen
# First Located Time:  2019-04-19T19:12:25.649+0300
# Last Located Time:  2019-04-19T19:48:38.487+0300
# userName:  osloboda
# RSSI:  -60
# x:  850.9389
# y:  425.72635
